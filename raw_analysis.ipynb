# %%
import pandas as pd
import requests
import json

# %%
df_key = pd.read_csv('../api_key.csv')
api_key = df_key['key'][0]

# %%
## import 1500 articles, 
## desk values, 
## Type of Material Values
## Section Name Values

response = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json? \
    q=election&api-key={api_key}')
response.status_code  ## 10 articles
# Out:
# 200

# %%
response_json = response.json()
response_json['response']['docs'][0]
# Out:
# {'abstract': 'K.P. Sharma Oli, who leads the nation’s largest communist party, is to take office on Monday.',
#  'web_url': 'https://www.nytimes.com/2024/07/14/world/asia/nepal-prime-minister-government.html',
#  'snippet': 'K.P. Sharma Oli, who leads the nation’s largest communist party, is to take office on Monday.',
#  'lead_paragraph': 'Nepal’s president on Sunday appointed a new prime minister, the latest in a revolving door of leaders that has left the country of 30 million in a continuous state of political uncertainty.',
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'xlarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2024/07/14/multimedia/14nepal-politics-hklt/14nepal-politics-hklt-articleLarge.jpg',
#    'height': 411,
#    'width': 600,
#    'legacy': {'xlarge': 'images/2024/07/14/multimedia/14nepal-politics-hklt/14nepal-politics-hklt-articleLarge.jpg',
#     'xlargewidth': 600,
# ...

# %%
with open('sample_article.json', 'w') as f:
    json.dump(response_json['response']['docs'][0], f)

for idx, art in enumerate(response_json['response']['docs']):
    with open(f'article_{idx}.json', 'w') as f:
        json.dump(art, f)
